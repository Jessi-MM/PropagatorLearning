# %% [markdown]
# # Notas
#
# ## Sobre `class ProtonTransfer`
#
#
# El constructor de la clase utiliza los siguientes valores:
# - n: Número de puntos en el grid para el método DVR
# - a: Punto inicial del grid [angstroms]
# - b: Punto final del grid [angstroms]
# - k: Número de eigenestados incluidos para el paquete inicial de onda
# - time: True o False. Determina si se utiliza un potencial dependiente del tiempo: True, o independiente del tiempo: False
#
# *Ejemplo*:
#
# `data = ProtonTransfer(k = 5, n = 32, a=-1.5, b=1.5, time=True)`
#
# ### Para generar un paquete de onda inicial aleatorio
#
# Se utiliza el método Wavepacket_Init:
#
# `data.Wavepacket_Init()`
#
# Devuelve un array de $n$ números complejos
#
# ### Para generar potenciales dependientes del tiempo:V(t) (valores aleatorios)
#
# Se utiliza el método vector_potential:
# `data.vector_potential(t)`
#
# Devuelve un array de $n$ números reales con el potencial [au] al tiempo t en cada punto del grid.
#
# ### Para generar potenciales independientes del tiempo: V (valores aleatorios)
#
# Se utiliza el método vector_potential:
# `data.vector_potential_TI()`
#
# Devuelve un array de $n$ números reales con el potencial [au] en cada punto del grid.
#
# ### Para generar un paquete de onda propagado al tiempo t con V(t)
#
# Se utiliza el método evolution_wp:
# `data.evolution_wp(t = 100, step = 1)`
#
# Devuelve un array de $n$ números complejos correspondientes a la evolución de un paquete inicial al tiempo t [fs], con pasos de 1 [fs].
#
#
# ### Para generar un paquete de onda propagado al tiempo t con V
#
# Se utiliza el método evolution_wp:
# `data.evolution_wp_TI(t = 100, step = 1)`
#
# Devuelve un array de $n$ números complejos correspondientes a la evolución de un paquete inicial al tiempo t [fs], con pasos de 1 [fs]. Para un potencial independiente del tiempo.
#
#
# ## Sobre `class Potential_System`
#
# Se utiliza para generar las funciones del modelo físico del potencial: [artículo principal](https://doi.org/10.1021/acs.jpclett.1c03117)

# %%
import random
import numpy as np
from numpy import ogrid
from numpy.linalg import eig
import matplotlib.pyplot as plt
import cmath
from scipy import integrate
# Enable interactive plot
# %matplotlib notebook
from tabulate import tabulate
import matplotlib.animation as anim
import os

plt.style.use('seaborn')

# %%
class Potential_System:
    
    def __init__(self, time = True, var_random = True):
        
        
        if time == True:  # Time Dependent Potential
            if var_random == True:
                self.V = 10*1.5936e-3  # Electronic coupling [kcal/mol] -> au
                self.w1 = random.uniform(1500,4000)*4.556e-6   # Frecuencies of the harmonic proton potentials [cm^-1] -> au
                self.w2 = random.uniform(1500,4000)*4.556e-6   # Frecuencies of the harmonic proton potentials [cm^-1] -> au
                self.l = random.uniform(0,10)*1.5936e-3  # Amplitude of the energy bias [kcal/mol] -> au
                self.x_eq = random.uniform(-10,10)*1.5936e-3  # Equilibrium energy bias [kcal/mol] -> au
                self.w_x = 0.0148*(1/41.34144)  # Frequency of the energy bias oscillations [fs^-1] -> au
                self.th_x = random.uniform(0, 2*np.pi)  # Initial phase. Zero for the time-independent potentials
                self.R_eq = random.uniform(0.2, 1.0)*(1/0.5291775)  # Equilibrium distance between the minima of the harmonic potential [0.1nm] -> au 
                self.R_0 = random.uniform(0, self.R_eq)  # Initial displacement from equilibrium
                self.w_R = random.uniform(100, 300)*4.556e-6  # Frecuency of the proton-donor-acceptor distance oscillation [cm^-1] -> au
                self.th_R = random.uniform(0, 2*np.pi)  # Random initial phase 
                self.m = 1836  #The proton mass [au]
            
            if var_random == False:
                self.V = 10*1.5936e-3  # Electronic coupling [kcal/mol] -> au
                self.w1 = float(input('Enter w1 (Frecuencies of the harmonic proton potentials [cm^-1]): \n'))*4.556e-6
                self.w2 = float(input('Enter w2 (Frecuencies of the harmonic proton potentials [cm^-1]): \n'))*4.556e-6
                self.l = float(input('Enter l (Amplitude of the energy bias [kcal/mol]): \n'))*1.5936e-3  # Amplitude of the energy bias [kcal/mol] -> au
                self.x_eq = float(input('Enter x_eq (Equilibrium energy bias [kcal/mol]): \n'))*1.5936e-3  # Equilibrium energy bias [kcal/mol] -> au
                self.w_x = 0.0148*(1/41.34144)  # Frequency of the energy bias oscillations [fs^-1] -> au
                self.th_x = float(input('Enter th_x (Initial phase from 0 to 2pi [rad]): \n'))  # Initial phase. Zero for the time-independent potentials
                self.R_eq = float(input('Enter R_eq (Equilibrium distance between the minima of the harmonic potential [0.1nm]): \n'))*(1/0.5291775)  # Equilibrium distance between the minima of the harmonic potential [0.1nm] -> au 
                self.R_0 = float(input('Enter R_0 (Initial displacement from equilibrium from 0 to R_eq [0.1nm]): \n'))*(1/0.5291775)  # Initial displacement from equilibrium
                self.w_R = float(input('Enter w_r (Frecuency of the proton-donor-acceptor distance oscillation [cm^-1]): \n'))*4.556e-6  # Frecuency of the proton-donor-acceptor distance oscillation [cm^-1] -> au
                self.th_R = float(input('Enter th_R (Random initial phase from 0 to 2pi [rad])'))  # Random initial phase 
                self.m = 1836  #The proton mass [au]
                
                
                
        if time == False:  # Time Independent Potential
            if var_random == False:
                self.V = 10*1.5936e-3  # Electronic coupling [kcal/mol] -> au
                self.w1 = float(input('Enter w1 (Frecuencies of the harmonic proton potentials [cm^-1]): \n'))*4.556e-6   # Frecuencies of the harmonic proton potentials [cm^-1] -> au
                self.w2 = float(input('Enter w2 (Frecuencies of the harmonic proton potentials [cm^-1]): \n'))*4.556e-6   # Frecuencies of the harmonic proton potentials [cm^-1] -> au
                self.x_eq = float(input('Enter x_eq (Equilibrium energy bias [kcal/mol]): \n'))*1.5936e-3 # Equilibrium energy bias [kcal/mol] -> au
                self.R_eq = float(input('Enter R_eq (Equilibrium distance between the minima of the harmonic potential [0.1nm]): \n'))*(1/0.5291775) # Equilibrium distance between the minima of the harmonic potential [0.1nm] -> au 
                self.m = 1836  #The proton mass [au]
                
            if var_random == True:
                self.V =  10*1.5936e-3 # Electronic coupling [kcal/mol] -> au
                self.w1 = random.uniform(1500,4000)*4.556e-6# Frecuencies of the harmonic proton potentials [cm^-1] -> au
                self.w2 = random.uniform(1500,4000)*4.556e-6   # Frecuencies of the harmonic proton potentials [cm^-1] -> au
                self.x_eq = random.uniform(-10,10)*1.5936e-3  # Equilibrium energy bias [kcal/mol] -> au
                self.R_eq = random.uniform(0.2, 1.0)*(1/0.5291775)  # Equilibrium distance between the minima of the harmonic potential [0.1nm] -> au 
                self.m = 1836  #The proton mass [au]
                
    '''            
    def get_values(self):
        if self.time == True:
            print("====== Time Dependent Potential ======")
            return print(tabulate([["V [kcal/mol]", self.V*(1/1.5936e-3)],["w1 [cm^-1]", self.w1*(1/4.556e-6)], ["w2 [cm^-1]", self.w2*(1/4.556e-6)], ["l [kcal/mol]", self.l*(1/1.5936e-3)], ["x_eq [kcal/mol]", self.x_eq*(1/1.5936e-3)], ["w_x [fs^-1]", self.w_x*(41.34144)], ["th_x [rad]", self.th_x], ["R_eq [0.1 nm]", self.R_eq*(0.5291775)], ["R_0 [0.1 nm]", self.R_0*(0.5291775)], ["w_R [cm^-1]", self.w_R*(1/4.556e-6)], ["th_R [rad]", self.th_R], ["m (Proton mass [au])", self.m]], headers=['Variable', 'Value'], tablefmt='orgtbl'))
        if self.time == False:
            print("====== Time Independent Potential ======")
            return print(tabulate([["V [kcal/mol]", self.V*(1/1.5936e-3)],["w1 [cm^-1]", self.w1*(1/4.556e-6)], ["w2 [cm^-1]", self.w2*(1/4.556e-6)], ["x_eq [kcal/mol]", self.x_eq*(1/1.5936e-3)], ["R_eq [0.1 nm]", self.R_eq*(0.5291775)], ["m (Proton mass [au])", self.m]], headers=['Variable', 'Value'], tablefmt='orgtbl'))
        
    '''
    #=== System Functions ================================== 
    
    #--- Time Dependent Potential --------------------------
    def X(self, t):
        """
        Variables:
        l : Amplitude of the energy bias [a_0]
        w_x: Frequency of the energy bias oscillations [Jiffy^-1]
        th_x: Initial phase
        x_eq: Equilibrium energy bias [au]
    
        Input:
        t: Time [Jiffy]
    
        Output:
        X_t: Collective energy gap coordinate [au]
        """
        X_t = self.l*np.cos(self.w_x*t+self.th_x) + self.x_eq
        return X_t
    
    
    def R(self, t):
        """
        Variables:
        R_0: Initial displacement from equilibrium [a_0]
        R_eq: Equilibrium distance between the minima of the harmonic potential [a_0]
        w_R: Frecuency of the proton-donor-acceptor distance oscillation [cm^-1]
        th_R: Random initial phase
    
        Input:
        t : Time [Jiffy]
    
        Output:
        R_t: Vibrations of the proton donor and acceptor [a_0]
        """
        R_t = (self.R_0-self.R_eq)*np.cos(self.w_R*t+self.th_R) + self.R_eq
        return R_t
    
    def u1(self, r, t):
        """
        Variables:
        m : Proton mass [m_e]
        w1: Frecuencies of the harmonic proton potentials [cm^-1]
        R(t): Vibrations of the proton donor and acceptor [a_0]
    
        Input:
        r: Proton coordinate [a_0]
        t: Time [Jify]
    
        Output:
        u1_t: Harmonic oscillator potential [au]
    
        """
        u1_t = (1/2)*self.m*(self.w1**2)*(r + (self.R(t)/2))**2
        return u1_t


    def u2(self, r, t):
        """
        Variables:
        m : Proton mass [m_e]
        w2: Frecuencies of the harmonic proton potentials [cm^-1]
        R(t): Vibrations of the proton donor and acceptor [a_0]
    
        Input:
        r: Proton coordinate [a_0]
        t: Time [Jiffy]
    
        Output:
        u2_t: Harmonic oscillator potential [au]
    
        """
        u2_t = (1/2)*self.m*(self.w2**2)*(r - (self.R(t)/2))**2
        return u2_t
    
    #=== Potential of system ==============================
    #--- Time Dependent Potential
    
    def matrix_potential(self, r, t):
        """
        Input:
        r: Proton coordinate [a_0]
        t: Time [Jiffy]
    
        Output:
        Potential Matrix
    
        """
        matrix = np.array([[self.u1(r,t),self.V],[self.V,self.u2(r,t) + self.X(t)]])
        return matrix
    
    def potential(self, r, t):
        """
        Input:
        r: Proton coordinate [a_0]
        t: Time [Jiffy]
    
        Output:
        The lowest eigenvalue of potential matrix  
        """
        e_val = np.linalg.eigvals(self.matrix_potential(r,t))
    
        if e_val[0] < e_val[1]:
            pot = e_val[0]
        else:
            pot = e_val[1]
        return pot
    
    #--- Time Independent Potential ----------------------------
    def u1_TI(self, r):
        """
        Variables:
        m : Proton mass [m_e]
        w1: Frecuencies of the harmonic proton potentials [cm^-1]
        R_eq: Vibrations of the proton donor and acceptor [a_0]
    
        Input:
        r: Proton coordinate [a_0]
    
        Output:
        u1_t: Harmonic oscillator potential [au]
    
        """
        u1_t = (1/2)*self.m*(self.w1**2)*(r + (self.R_eq/2))**2
        return u1_t


    def u2_TI(self, r):
        """
        Variables:
        m : Proton mass [m_e]
        w2: Frecuencies of the harmonic proton potentials [cm^-1]
        R_eq: Vibrations of the proton donor and acceptor [a_0]
    
        Input:
        r: Proton coordinate [a_0]
    
        Output:
        u2_t: Harmonic oscillator potential [au]
    
        """
        u2_t = (1/2)*self.m*(self.w2**2)*(r - (self.R_eq/2))**2
        return u2_t
    
    #=== Potential of system ==============================
    #--- Time Independent Potential
    
    def matrix_potential_TI(self, r):
        """
        Input:
        r: Proton coordinate [a_0]
    
        Output:
        Potential Matrix
    
        """
        matrix = np.array([[self.u1_TI(r),self.V],[self.V,self.u2_TI(r) + self.x_eq]])
        return matrix
    
    def potential_TI(self, r):
        """
        Input:
        r: Proton coordinate [a_0]
    
        Output:
        The lowest eigenvalue of potential matrix  
        """
        e_val = np.linalg.eigvals(self.matrix_potential_TI(r))
    
        if e_val[0] < e_val[1]:
            pot = e_val[0]
        else:
            pot = e_val[1]
        return pot

# %%
class ProtonTransfer(Potential_System):
    
    def __init__(self, n, a, b, k, time, var_random, save_dir):
        """
        Input:
        n: Number of points on the grid to DVR method
        a: Initial point of grid [angstroms]
        b: Final point of grid [angstroms]
        k: Number of eigenestatos included in the initial wavepacket
        
        Output:
        a,b & grid r_n in atomic units: au 
        """
        
        self.n = n  # Number of points on the grid to DVR method
        self.a = a*(1/0.5291775)  # Initial point of grid [au]
        self.b = b*(1/0.5291775)  # Final point of grid [au]
        self.k = k  # Number of eigenestatos included in the initial wavepacket
        self.time = time  # True: Time Dependent Potential / False: Time Independent Potential
        self.var_random = var_random  # True: Initialization with random values 
        self.save_dir = save_dir
        
        os.makedirs('./'+self.save_dir+'/Wavepacket')
        os.makedirs('./'+self.save_dir+'/Potential')
        
        self.r_n = ogrid[self.a:self.b:(0+1j)*self.n]  # Grid position [au]
        super().__init__(time = self.time, var_random = self.var_random)
        
    
    def get_values_Potential(self):
        if self.time == True:
            with open('./'+self.save_dir+'/Values_PotentialSystem.txt', 'w') as f:
                f.write('====== Time Dependent Potential ======\n')
                f.write(tabulate([["V [kcal/mol]", self.V*(1/1.5936e-3)],["w1 [cm^-1]", self.w1*(1/4.556e-6)], ["w2 [cm^-1]", self.w2*(1/4.556e-6)], ["l [kcal/mol]", self.l*(1/1.5936e-3)], ["x_eq [kcal/mol]", self.x_eq*(1/1.5936e-3)], ["w_x [fs^-1]", self.w_x*(41.34144)], ["th_x [rad]", self.th_x], ["R_eq [0.1 nm]", self.R_eq*(0.5291775)], ["R_0 [0.1 nm]", self.R_0*(0.5291775)], ["w_R [cm^-1]", self.w_R*(1/4.556e-6)], ["th_R [rad]", self.th_R], ["m (Proton mass [au])", self.m]], headers=['Variable', 'Value'], tablefmt='orgtbl'))
            print('====== Time Dependent Potential ======\n')
            return print(tabulate([["V [kcal/mol]", self.V*(1/1.5936e-3)],["w1 [cm^-1]", self.w1*(1/4.556e-6)], ["w2 [cm^-1]", self.w2*(1/4.556e-6)], ["l [kcal/mol]", self.l*(1/1.5936e-3)], ["x_eq [kcal/mol]", self.x_eq*(1/1.5936e-3)], ["w_x [fs^-1]", self.w_x*(41.34144)], ["th_x [rad]", self.th_x], ["R_eq [0.1 nm]", self.R_eq*(0.5291775)], ["R_0 [0.1 nm]", self.R_0*(0.5291775)], ["w_R [cm^-1]", self.w_R*(1/4.556e-6)], ["th_R [rad]", self.th_R], ["m (Proton mass [au])", self.m]], headers=['Variable', 'Value'], tablefmt='orgtbl'))
        
        if self.time == False:
            with open('./'+self.save_dir+'/Values_PotentialSystem.txt', 'w') as f:
                f.write('====== Time Independent Potential ======')
                f.write((tabulate([["V [kcal/mol]", self.V*(1/1.5936e-3)],["w1 [cm^-1]", self.w1*(1/4.556e-6)], ["w2 [cm^-1]", self.w2*(1/4.556e-6)], ["x_eq [kcal/mol]", self.x_eq*(1/1.5936e-3)], ["R_eq [0.1 nm]", self.R_eq*(0.5291775)], ["m (Proton mass [au])", self.m]], headers=['Variable', 'Value'], tablefmt='orgtbl')))
            print("====== Time Independent Potential ======")
            return print(tabulate([["V [kcal/mol]", self.V*(1/1.5936e-3)],["w1 [cm^-1]", self.w1*(1/4.556e-6)], ["w2 [cm^-1]", self.w2*(1/4.556e-6)], ["x_eq [kcal/mol]", self.x_eq*(1/1.5936e-3)], ["R_eq [0.1 nm]", self.R_eq*(0.5291775)], ["m (Proton mass [au])", self.m]], headers=['Variable', 'Value'], tablefmt='orgtbl'))
        
        
    def get_values_Trajectory(self, t, step):
        with open('./'+self.save_dir+'/Values_Trajectory.txt', 'w') as f:
                f.write(tabulate([["Divisiones en el grid (n):", self.n],["Number of eigenstates to generate the initial wavepacket (k):", self.k],["Time of trajectory (t):", t], ["Step of trajectory:", step]],headers=['Variable', 'Value'], tablefmt='orgtbl'))
        
    
    
    
    

    #=== Random wavepacket initial =============================================
        
    def __eigenestados__(self, r, m):
        a1 = self.a*0.5291775  # au -> angstroms
        b1 = self.b*0.5291775  # au -> angstroms
        e_m =((2/(self.b-self.a))**(1/2))*np.sin((m*np.pi*(r-self.a))/(self.b-self.a))
        return e_m
        
    
    def __phi_i__(self, m):
        phi = np.zeros(self.n)
        j = 0
        for j, i in enumerate(self.r_n):
            phi[j] = self.__eigenestados__(i, m)
        return phi
    
    def __random_Ci__(self):
        cix = random.random()
        ciy = random.random()
        Ci = complex(cix,ciy)
        return Ci
    
    def Wavepacket_Init(self):
        #random.seed(0)
        Ci_norm = []
        wavei = np.zeros([self.k,self.n], dtype = 'complex_')
        for i in range(1,self.k+1):
            Ci = self.__random_Ci__()
            Ci_norm.append(np.abs(Ci)**2)
            wavei[i-1,:] = Ci*(self.__phi_i__(i))
        wave = sum(wavei[i] for i in range(self.k))         
        
        return wave/np.sqrt(sum(Ci_norm))
    
    
    def gaussi(self):
        mu = np.random.uniform(-0.5,0.5)*(1/0.5291775)
        sigma = np.random.uniform(0.1,0.3)*(1/0.5291775)
        Ci = self.__random_Ci__()
        g = Ci*(1/sigma*np.sqrt(2*np.pi))*np.exp(-((self.r_n-mu)**2)/(2*sigma**2))
    
        norm = integrate.simpson((np.abs(g)**2), self.r_n)
        return g/np.sqrt(norm)
    
    
    
    #=== Vector Potential =======================================
    
    def vector_potential(self, t, step=1):
        """
        Input:
        t: Time [fs]
    
        Output:
        Potential in the grid at time t (lenght: 32)
        """
        for j in range(0,t+1, step):
            v_pot = np.zeros(self.n)
            for i, item in enumerate(self.r_n):
                v_pot[i] = self.potential(item,j*41.34)  # fs -> au
            with open(os.path.join('./'+self.save_dir+'/Potential', str(j)+'-potential.npy'), 'wb') as f:
                np.save(f, v_pot)
            
        
        return v_pot
        
    
    def vector_potential_TI(self):
        """
    
        Output:
        Potential in the grid (lenght: 32)
        """
        v_pot = np.zeros(self.n)
        for i, item in enumerate(self.r_n):
            v_pot[i] = self.potential_TI(item)
            
        with open(os.path.join('./'+self.save_dir+'/Potential', str(t)+'-potential.npy'), 'wb') as f:
                np.save(f, v_pot)
        
        return v_pot
    
    
    #=== Kinetic Energy Matrix =================================
    def __senno__(self, k,l,n):
        y = (n**2)*(np.sin((n*np.pi*k)/self.n))*(np.sin((n*np.pi*l)/self.n))
        return y


    def KINETIC_DVR(self):
        h_bar = 1  # Constante de Planck en au
        T_c = ((h_bar**2)/(2*self.m))*((np.pi/(self.b-self.a))**2)*(2/self.n)
        T1 = np.arange(1,self.n-1)
    
        T_DVR = np.zeros((self.n,self.n))  # Matriz de enerfía cinética (fija) [au]

        for i in range(1,self.n-1):
            for j in range(1,self.n-1):
                c = []
                for n in T1:
                    c.append(self.__senno__(i,j,n))
                T_DVR[i,j] = T_c*sum(c)
        
        return T_DVR
    
    #=== Potential Matrix ==============================
    def V_DVR(self, t):
        """
        Input: t [au]
    
        Output: Matriz de potencial en el grid: V_DVR [au]
        """
        V = np.zeros((self.n,self.n))
    
        for i, r in enumerate(self.r_n):
            V[i,i] = self.potential(r,(t))#*(1/1.5936e-3)  # time: fs -> au, energy: Hartree -> kcal/mol
        
        return V
    
    #=== Hamiltonian Matrix ==============================
    def H_DVR(self,t):
        """
        input: tiempo [fs]
    
        output: Matriz Hamiltoniana DVR [au]
        """
        T_DVR = self.KINETIC_DVR()
        t = t*41.34  # fs -> au
        H = T_DVR + self.V_DVR(t)
        return H
    
    
    #=== Time Independent Potential Matrix ==============================
    def V_DVR_TI(self):
        """
        Output: Matriz de potencial en el grid: V_DVR [au]
        """
        V = np.zeros((self.n,self.n))
    
        for i, r in enumerate(self.r_n):
            V[i,i] = self.potential_TI(r)#*(1/1.5936e-3)  # time: fs -> au, energy: Hartree -> kcal/mol
        
        return V
    
    #=== Time Independent Hamiltonian Matrix ==============================
    def H_DVR_TI(self):
        """
    
        output: Matriz Hamiltoniana DVR [au]
        """
        T_DVR = self.KINETIC_DVR()
        H = T_DVR + self.V_DVR_TI()
        return H
    
    
    
    
    
    
    #=== Propagation wavepacket Time Dependent Potential ==========================
    # Find eigenvalues and eigenvectors:
    def eigenN(self,t):
        Eigen_n, U = eig(self.H_DVR(t))
    
        U_inv = np.linalg.inv(U)
    
        D = np.dot(np.dot(U_inv, self.H_DVR(t)),U)
        D = (complex(0,-1))*t*D
        
        return Eigen_n, U, U_inv, D
    
    
    def Psi_VDR_t(self, t, Psi_DVR_inicial):
    
        Eigen_n, U, U_inv, D = self.eigenN(t)
    
        Diag = np.zeros([self.n,self.n], dtype = 'complex_')
        for i in range(self.n):
            Diag[i][i] = np.exp(np.diagonal(D))[i]
    
    
        Psi_DVR_final = np.dot((np.dot(np.dot(U, Diag),U_inv)),Psi_DVR_inicial)
        
        # Normalization
        norm = integrate.simpson((np.abs(Psi_DVR_final)**2), self.r_n)
        
    
        return Psi_DVR_final/np.sqrt(norm)
    
    
    def evolution_wp(self, t, step, gaussiana):
        """
        Función que calcula la evolución del wavepacket inicial a un tiempo t bajo el potencial dado.
        Los intervalos de tiempo son de 1 fs
    
        Input:
        t: tiempo de evolución [fs]
    
        Output:
        wp: Wavepacket evolucionado con el método DVR bajo el potencial V(t)
        """
        
        #-if t == 0:
            #-wp = self.Wavepacket_Init()
            #-with open(os.path.join('./'+self.save_dir+'/Wavepacket', str(t)+'-wave.npy'), 'wb') as f:
                #-np.save(f, wp)
            #-return wp
        if t == 0:
            if gaussiana==True:
                wp = self.gaussi()
                with open(os.path.join('./'+self.save_dir+'/Wavepacket', str(t)+'-wave.npy'), 'wb') as f:
                    np.save(f, wp)
                return wp
            if gaussiana==False:
                wp = self.Wavepacket_Init()
                with open(os.path.join('./'+self.save_dir+'/Wavepacket', str(t)+'-wave.npy'), 'wb') as f:
                    np.save(f, wp)
                return wp
                
        
        else:
            wp = self.Psi_VDR_t(t, self.evolution_wp(t-step, step, gaussiana))
            with open(os.path.join('./'+self.save_dir+'/Wavepacket', str(t)+'-wave.npy'), 'wb') as f:
                np.save(f, wp)
                
        
            return wp

    
    
    #=== Time Independent Propagation wavepacket ==========================
    # Find eigenvalues and eigenvectors:
    def eigenN_TI(self):
        Eigen_n, U = eig(self.H_DVR_TI())
    
        U_inv = np.linalg.inv(U)
    
        D = np.dot(np.dot(U_inv, self.H_DVR_TI()),U)
        D = (complex(0,-1))*t*D
        
        return Eigen_n, U, U_inv, D
    
    
    def Psi_VDR_t_TI(self, Psi_DVR_inicial):
    
        Eigen_n, U, U_inv, D = self.eigenN_TI()
    
        Diag = np.zeros([self.n,self.n], dtype = 'complex_')
        for i in range(self.n):
            Diag[i][i] = np.exp(np.diagonal(D))[i]
    
    
        Psi_DVR_final = np.dot((np.dot(np.dot(U, Diag),U_inv)),Psi_DVR_inicial)
    
        # Normalizacion:
        norm = integrate.simpson((np.abs(Psi_DVR_final)**2), self.r_n)

        
    
        return Psi_DVR_final/np.sqrt(norm)
    
    
    def evolution_wp_TI(self, t, step, gaussiana):
        """
        Función que calcula la evolución del wavepacket inicial a un tiempo t bajo el potencial dado.
        Los intervalos de tiempo son de 1 fs
        * Colocar múltiplos enteros de step
    
        Input:
        t: tiempo de evolución [fs]
    
        Output:
        wp: Wavepacket evolucionado con el método DVR bajo el potencial V(t)
        """
        if t == 0:
            if gaussiana == False:
                wp = self.Wavepacket_Init()
                with open(os.path.join('./'+self.save_dir+'/Wavepacket', str(t)+'-wave.npy'), 'wb') as f:
                    np.save(f, wp)
                return wp 
            if gaussiana == True:
                wp = self.gaussi()
                with open(os.path.join('./'+self.save_dir+'/Wavepacket', str(t)+'-wave.npy'), 'wb') as f:
                    np.save(f, wp)
                return wp 
        else:
            wp = self.Psi_VDR_t_TI(self.evolution_wp_TI(t-step, step, gaussiana))
            with open(os.path.join('./'+self.save_dir+'/Wavepacket', str(t)+'-wave.npy'), 'wb') as f:
                np.save(f, wp)
            return wp
    
    
    def density(self, wavepacket):
        dens = (np.abs(wavepacket))**2
        return dens

# %% [markdown]
# # Type II: Time Dependent Potential
#
#
# # Datos con gaussianas, n=32, Trajectoryes = 200 fs, tstep = 1 fs

# %%
for i in range(0,200,1):
    d = ProtonTransfer(n=1, a=-1.5, b=1.5, k=5, time=True, var_random=True, save_dir='data'+str(i))
    d.vector_potential(200, step=1)
    d.get_values_Potential()
    d.get_values_Trajectory(200, step=1)
    d.evolution_wp(200, step=1, gaussiana=True)
# Out:
# ====== Time Dependent Potential ======
#
# | Variable             |         Value |
# |----------------------+---------------|
# | V [kcal/mol]         |   10          |
# | w1 [cm^-1]           | 2709.97       |
# | w2 [cm^-1]           | 1607.42       |
# | l [kcal/mol]         |    2.84254    |
# | x_eq [kcal/mol]      |   -2.14944    |
# | w_x [fs^-1]          |    0.0148     |
# | th_x [rad]           |    0.857276   |
# | R_eq [0.1 nm]        |    0.213357   |
# | R_0 [0.1 nm]         |    0.00108046 |
# | w_R [cm^-1]          |  211.406      |
# | th_R [rad]           |    3.8343     |
# | m (Proton mass [au]) | 1836          |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3524.92      |
# | w2 [cm^-1]           | 3333.06      |
# | l [kcal/mol]         |    0.0992178 |
# | x_eq [kcal/mol]      |   -7.675     |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    2.95993   |
# | R_eq [0.1 nm]        |    0.653203  |
# | R_0 [0.1 nm]         |    0.593729  |
# | w_R [cm^-1]          |  144.429     |
# | th_R [rad]           |    2.11189   |
# | m (Proton mass [au]) | 1836         |
# /tmp/ipykernel_38378/2189193969.py:97: RuntimeWarning: divide by zero encountered in true_divide
#   return g/np.sqrt(norm)
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1755.34     |
# | w2 [cm^-1]           | 2299.52     |
# | l [kcal/mol]         |    6.27685  |
# | x_eq [kcal/mol]      |   -0.992154 |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.42293  |
# | R_eq [0.1 nm]        |    0.920555 |
# | R_0 [0.1 nm]         |    0.106684 |
# | w_R [cm^-1]          |  136.9      |
# | th_R [rad]           |    4.69845  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2649.56     |
# | w2 [cm^-1]           | 2753.88     |
# | l [kcal/mol]         |    2.74699  |
# | x_eq [kcal/mol]      |   -6.41144  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.14463  |
# | R_eq [0.1 nm]        |    0.444617 |
# | R_0 [0.1 nm]         |    0.257601 |
# | w_R [cm^-1]          |  252.744    |
# | th_R [rad]           |    5.88669  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3855.16      |
# | w2 [cm^-1]           | 2478.99      |
# | l [kcal/mol]         |    6.74053   |
# | x_eq [kcal/mol]      |    0.355795  |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    5.83669   |
# | R_eq [0.1 nm]        |    0.461786  |
# | R_0 [0.1 nm]         |    0.0122888 |
# | w_R [cm^-1]          |  191.625     |
# | th_R [rad]           |    2.22888   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3811.44      |
# | w2 [cm^-1]           | 3227.23      |
# | l [kcal/mol]         |    2.24001   |
# | x_eq [kcal/mol]      |   -2.9965    |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    5.67031   |
# | R_eq [0.1 nm]        |    0.841405  |
# | R_0 [0.1 nm]         |    0.0291551 |
# | w_R [cm^-1]          |  167.639     |
# | th_R [rad]           |    1.63742   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2666.36     |
# | w2 [cm^-1]           | 3966.33     |
# | l [kcal/mol]         |    6.36659  |
# | x_eq [kcal/mol]      |    4.57274  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.31275  |
# | R_eq [0.1 nm]        |    0.545444 |
# | R_0 [0.1 nm]         |    0.38284  |
# | w_R [cm^-1]          |  235.19     |
# | th_R [rad]           |    1.16709  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2903.88     |
# | w2 [cm^-1]           | 1516.8      |
# | l [kcal/mol]         |    9.34012  |
# | x_eq [kcal/mol]      |    8.21654  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    6.01868  |
# | R_eq [0.1 nm]        |    0.286107 |
# | R_0 [0.1 nm]         |    0.199848 |
# | w_R [cm^-1]          |  159.731    |
# | th_R [rad]           |    1.19966  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1964.28     |
# | w2 [cm^-1]           | 3537.79     |
# | l [kcal/mol]         |    9.90431  |
# | x_eq [kcal/mol]      |    7.25861  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.02221  |
# | R_eq [0.1 nm]        |    0.763325 |
# | R_0 [0.1 nm]         |    0.392644 |
# | w_R [cm^-1]          |  132.315    |
# | th_R [rad]           |    3.20783  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3460.57      |
# | w2 [cm^-1]           | 3302.1       |
# | l [kcal/mol]         |    9.42517   |
# | x_eq [kcal/mol]      |    1.76253   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    0.0157162 |
# | R_eq [0.1 nm]        |    0.748035  |
# | R_0 [0.1 nm]         |    0.644632  |
# | w_R [cm^-1]          |  246.324     |
# | th_R [rad]           |    0.766191  |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2989.88      |
# | w2 [cm^-1]           | 2404.11      |
# | l [kcal/mol]         |    3.01312   |
# | x_eq [kcal/mol]      |   -5.14298   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    4.58514   |
# | R_eq [0.1 nm]        |    0.775556  |
# | R_0 [0.1 nm]         |    0.0143047 |
# | w_R [cm^-1]          |  284.978     |
# | th_R [rad]           |    5.87206   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2148.23     |
# | w2 [cm^-1]           | 1932.42     |
# | l [kcal/mol]         |    0.545109 |
# | x_eq [kcal/mol]      |   -3.24604  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.25002  |
# | R_eq [0.1 nm]        |    0.341104 |
# | R_0 [0.1 nm]         |    0.126466 |
# | w_R [cm^-1]          |  103.336    |
# | th_R [rad]           |    0.45388  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3691.57     |
# | w2 [cm^-1]           | 3271.3      |
# | l [kcal/mol]         |    7.8626   |
# | x_eq [kcal/mol]      |   -3.31854  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.21057  |
# | R_eq [0.1 nm]        |    0.635933 |
# | R_0 [0.1 nm]         |    0.615893 |
# | w_R [cm^-1]          |  276.883    |
# | th_R [rad]           |    3.84428  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2435.04      |
# | w2 [cm^-1]           | 2297.9       |
# | l [kcal/mol]         |    2.20625   |
# | x_eq [kcal/mol]      |    0.0397807 |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    2.85931   |
# | R_eq [0.1 nm]        |    0.868668  |
# | R_0 [0.1 nm]         |    0.293663  |
# | w_R [cm^-1]          |  270.543     |
# | th_R [rad]           |    4.82484   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3384.63      |
# | w2 [cm^-1]           | 3801.96      |
# | l [kcal/mol]         |    1.32157   |
# | x_eq [kcal/mol]      |   -0.0495961 |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    2.20839   |
# | R_eq [0.1 nm]        |    0.685592  |
# | R_0 [0.1 nm]         |    0.0496069 |
# | w_R [cm^-1]          |  185.094     |
# | th_R [rad]           |    5.91687   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3032.4      |
# | w2 [cm^-1]           | 2345.8      |
# | l [kcal/mol]         |    4.07967  |
# | x_eq [kcal/mol]      |   -7.70471  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.04286  |
# | R_eq [0.1 nm]        |    0.788005 |
# | R_0 [0.1 nm]         |    0.353257 |
# | w_R [cm^-1]          |  262.034    |
# | th_R [rad]           |    1.74442  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1927.73     |
# | w2 [cm^-1]           | 2855.46     |
# | l [kcal/mol]         |    4.48221  |
# | x_eq [kcal/mol]      |   -7.15545  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.00546  |
# | R_eq [0.1 nm]        |    0.305714 |
# | R_0 [0.1 nm]         |    0.293953 |
# | w_R [cm^-1]          |  100.052    |
# | th_R [rad]           |    5.58004  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1594.87     |
# | w2 [cm^-1]           | 2240.79     |
# | l [kcal/mol]         |    9.47823  |
# | x_eq [kcal/mol]      |   -4.70803  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.37531  |
# | R_eq [0.1 nm]        |    0.3284   |
# | R_0 [0.1 nm]         |    0.309035 |
# | w_R [cm^-1]          |  253.266    |
# | th_R [rad]           |    0.49117  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2579.65     |
# | w2 [cm^-1]           | 2929.93     |
# | l [kcal/mol]         |    9.77121  |
# | x_eq [kcal/mol]      |   -5.25246  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.29331  |
# | R_eq [0.1 nm]        |    0.771788 |
# | R_0 [0.1 nm]         |    0.557127 |
# | w_R [cm^-1]          |  246.118    |
# | th_R [rad]           |    3.32523  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3496.57      |
# | w2 [cm^-1]           | 3031.77      |
# | l [kcal/mol]         |    3.80145   |
# | x_eq [kcal/mol]      |    0.781864  |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    3.58984   |
# | R_eq [0.1 nm]        |    0.820394  |
# | R_0 [0.1 nm]         |    0.0549888 |
# | w_R [cm^-1]          |  109.212     |
# | th_R [rad]           |    2.85008   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2132.44     |
# | w2 [cm^-1]           | 1594.54     |
# | l [kcal/mol]         |    1.01946  |
# | x_eq [kcal/mol]      |    4.91643  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.5845   |
# | R_eq [0.1 nm]        |    0.281111 |
# | R_0 [0.1 nm]         |    0.101208 |
# | w_R [cm^-1]          |  254.649    |
# | th_R [rad]           |    4.54168  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1856.75     |
# | w2 [cm^-1]           | 3216.75     |
# | l [kcal/mol]         |    7.33938  |
# | x_eq [kcal/mol]      |    1.43804  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.01267  |
# | R_eq [0.1 nm]        |    0.772856 |
# | R_0 [0.1 nm]         |    0.35492  |
# | w_R [cm^-1]          |  109.263    |
# | th_R [rad]           |    2.7161   |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3627.69     |
# | w2 [cm^-1]           | 1558.24     |
# | l [kcal/mol]         |    8.04606  |
# | x_eq [kcal/mol]      |    3.52413  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.407509 |
# | R_eq [0.1 nm]        |    0.465788 |
# | R_0 [0.1 nm]         |    0.137752 |
# | w_R [cm^-1]          |  282.796    |
# | th_R [rad]           |    5.3555   |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3599.61      |
# | w2 [cm^-1]           | 2216.62      |
# | l [kcal/mol]         |    4.9371    |
# | x_eq [kcal/mol]      |    7.80597   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    3.81538   |
# | R_eq [0.1 nm]        |    0.765856  |
# | R_0 [0.1 nm]         |    0.0932037 |
# | w_R [cm^-1]          |  276.737     |
# | th_R [rad]           |    3.95821   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2220.99      |
# | w2 [cm^-1]           | 3377.14      |
# | l [kcal/mol]         |    3.46361   |
# | x_eq [kcal/mol]      |   -1.52741   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    3.32373   |
# | R_eq [0.1 nm]        |    0.311128  |
# | R_0 [0.1 nm]         |    0.0568913 |
# | w_R [cm^-1]          |  182.808     |
# | th_R [rad]           |    2.24118   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2809.05     |
# | w2 [cm^-1]           | 3081.87     |
# | l [kcal/mol]         |    0.546781 |
# | x_eq [kcal/mol]      |    4.94568  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.50721  |
# | R_eq [0.1 nm]        |    0.534179 |
# | R_0 [0.1 nm]         |    0.082786 |
# | w_R [cm^-1]          |  291.462    |
# | th_R [rad]           |    2.79306  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3258.03     |
# | w2 [cm^-1]           | 3456.46     |
# | l [kcal/mol]         |    8.15668  |
# | x_eq [kcal/mol]      |    2.68503  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.92544  |
# | R_eq [0.1 nm]        |    0.68057  |
# | R_0 [0.1 nm]         |    0.661208 |
# | w_R [cm^-1]          |  269.413    |
# | th_R [rad]           |    3.11139  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3045.54     |
# | w2 [cm^-1]           | 3247.42     |
# | l [kcal/mol]         |    5.17552  |
# | x_eq [kcal/mol]      |    9.57512  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.62897  |
# | R_eq [0.1 nm]        |    0.425036 |
# | R_0 [0.1 nm]         |    0.310934 |
# | w_R [cm^-1]          |  191.833    |
# | th_R [rad]           |    1.52248  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2573.97     |
# | w2 [cm^-1]           | 3875.2      |
# | l [kcal/mol]         |    0.936456 |
# | x_eq [kcal/mol]      |    0.873289 |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.83903  |
# | R_eq [0.1 nm]        |    0.489218 |
# | R_0 [0.1 nm]         |    0.311518 |
# | w_R [cm^-1]          |  147.798    |
# | th_R [rad]           |    3.88811  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2623.38     |
# | w2 [cm^-1]           | 1914.57     |
# | l [kcal/mol]         |    4.22442  |
# | x_eq [kcal/mol]      |   -0.772291 |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.20744  |
# | R_eq [0.1 nm]        |    0.697165 |
# | R_0 [0.1 nm]         |    0.685711 |
# | w_R [cm^-1]          |  299.166    |
# | th_R [rad]           |    3.15851  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2102.94     |
# | w2 [cm^-1]           | 1807.86     |
# | l [kcal/mol]         |    4.919    |
# | x_eq [kcal/mol]      |    7.50358  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.771754 |
# | R_eq [0.1 nm]        |    0.348073 |
# | R_0 [0.1 nm]         |    0.328398 |
# | w_R [cm^-1]          |  207.858    |
# | th_R [rad]           |    6.20812  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3944.98     |
# | w2 [cm^-1]           | 3497.47     |
# | l [kcal/mol]         |    6.18101  |
# | x_eq [kcal/mol]      |   -5.96716  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.21708  |
# | R_eq [0.1 nm]        |    0.311604 |
# | R_0 [0.1 nm]         |    0.099969 |
# | w_R [cm^-1]          |  296.713    |
# | th_R [rad]           |    2.05356  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3163.65     |
# | w2 [cm^-1]           | 2934.29     |
# | l [kcal/mol]         |    9.03161  |
# | x_eq [kcal/mol]      |    7.16499  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.451089 |
# | R_eq [0.1 nm]        |    0.833834 |
# | R_0 [0.1 nm]         |    0.631213 |
# | w_R [cm^-1]          |  139.851    |
# | th_R [rad]           |    6.1754   |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3324.55     |
# | w2 [cm^-1]           | 2765.29     |
# | l [kcal/mol]         |    7.50642  |
# | x_eq [kcal/mol]      |    8.76111  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.27035  |
# | R_eq [0.1 nm]        |    0.51061  |
# | R_0 [0.1 nm]         |    0.356665 |
# | w_R [cm^-1]          |  281.538    |
# | th_R [rad]           |    3.58558  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3762.49      |
# | w2 [cm^-1]           | 3835.93      |
# | l [kcal/mol]         |    5.54304   |
# | x_eq [kcal/mol]      |   -6.33519   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    3.8995    |
# | R_eq [0.1 nm]        |    0.495678  |
# | R_0 [0.1 nm]         |    0.0901617 |
# | w_R [cm^-1]          |  139.293     |
# | th_R [rad]           |    4.95459   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3072.55     |
# | w2 [cm^-1]           | 2376.45     |
# | l [kcal/mol]         |    0.333322 |
# | x_eq [kcal/mol]      |    6.85715  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.03968  |
# | R_eq [0.1 nm]        |    0.341162 |
# | R_0 [0.1 nm]         |    0.229367 |
# | w_R [cm^-1]          |  167.695    |
# | th_R [rad]           |    1.4324   |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2512.57     |
# | w2 [cm^-1]           | 3162.5      |
# | l [kcal/mol]         |    8.24817  |
# | x_eq [kcal/mol]      |    9.35837  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.16279  |
# | R_eq [0.1 nm]        |    0.52765  |
# | R_0 [0.1 nm]         |    0.268433 |
# | w_R [cm^-1]          |  225.989    |
# | th_R [rad]           |    5.2158   |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2126.39     |
# | w2 [cm^-1]           | 2359.36     |
# | l [kcal/mol]         |    7.74346  |
# | x_eq [kcal/mol]      |   -2.86506  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.19712  |
# | R_eq [0.1 nm]        |    0.797559 |
# | R_0 [0.1 nm]         |    0.138861 |
# | w_R [cm^-1]          |  107.452    |
# | th_R [rad]           |    2.07224  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1852.55     |
# | w2 [cm^-1]           | 1597.36     |
# | l [kcal/mol]         |    5.49603  |
# | x_eq [kcal/mol]      |   -1.15917  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.18913  |
# | R_eq [0.1 nm]        |    0.718431 |
# | R_0 [0.1 nm]         |    0.265492 |
# | w_R [cm^-1]          |  111.861    |
# | th_R [rad]           |    2.75492  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2897.92     |
# | w2 [cm^-1]           | 2312.5      |
# | l [kcal/mol]         |    1.48729  |
# | x_eq [kcal/mol]      |   -4.96661  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.531692 |
# | R_eq [0.1 nm]        |    0.98789  |
# | R_0 [0.1 nm]         |    0.866834 |
# | w_R [cm^-1]          |  154.51     |
# | th_R [rad]           |    5.3429   |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2533.52     |
# | w2 [cm^-1]           | 1800.95     |
# | l [kcal/mol]         |    2.21767  |
# | x_eq [kcal/mol]      |    7.39153  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.479113 |
# | R_eq [0.1 nm]        |    0.737793 |
# | R_0 [0.1 nm]         |    0.369423 |
# | w_R [cm^-1]          |  124.006    |
# | th_R [rad]           |    2.31882  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2494.38      |
# | w2 [cm^-1]           | 3379.2       |
# | l [kcal/mol]         |    7.84453   |
# | x_eq [kcal/mol]      |    5.64277   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    4.67192   |
# | R_eq [0.1 nm]        |    0.26448   |
# | R_0 [0.1 nm]         |    0.0159782 |
# | w_R [cm^-1]          |  223.854     |
# | th_R [rad]           |    1.13659   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1561.54     |
# | w2 [cm^-1]           | 1861.21     |
# | l [kcal/mol]         |    3.72333  |
# | x_eq [kcal/mol]      |   -3.82387  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.27211  |
# | R_eq [0.1 nm]        |    0.515231 |
# | R_0 [0.1 nm]         |    0.315445 |
# | w_R [cm^-1]          |  151.868    |
# | th_R [rad]           |    0.469429 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1554.35     |
# | w2 [cm^-1]           | 2194.37     |
# | l [kcal/mol]         |    9.03625  |
# | x_eq [kcal/mol]      |    3.77404  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.32337  |
# | R_eq [0.1 nm]        |    0.298399 |
# | R_0 [0.1 nm]         |    0.178895 |
# | w_R [cm^-1]          |  229.96     |
# | th_R [rad]           |    2.11445  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3888.73     |
# | w2 [cm^-1]           | 1751.53     |
# | l [kcal/mol]         |    4.59648  |
# | x_eq [kcal/mol]      |   -0.213506 |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.93011  |
# | R_eq [0.1 nm]        |    0.931105 |
# | R_0 [0.1 nm]         |    0.630255 |
# | w_R [cm^-1]          |  149.542    |
# | th_R [rad]           |    0.129131 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3193.15     |
# | w2 [cm^-1]           | 1809.09     |
# | l [kcal/mol]         |    9.89777  |
# | x_eq [kcal/mol]      |   -8.68905  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.63177  |
# | R_eq [0.1 nm]        |    0.63179  |
# | R_0 [0.1 nm]         |    0.350769 |
# | w_R [cm^-1]          |  292.489    |
# | th_R [rad]           |    0.165824 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2244.08     |
# | w2 [cm^-1]           | 1582.81     |
# | l [kcal/mol]         |    3.01604  |
# | x_eq [kcal/mol]      |   -5.80043  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.89257  |
# | R_eq [0.1 nm]        |    0.29222  |
# | R_0 [0.1 nm]         |    0.067101 |
# | w_R [cm^-1]          |  138.44     |
# | th_R [rad]           |    3.2277   |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 1966.56      |
# | w2 [cm^-1]           | 3922.84      |
# | l [kcal/mol]         |    4.35513   |
# | x_eq [kcal/mol]      |    4.22138   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    3.48425   |
# | R_eq [0.1 nm]        |    0.603401  |
# | R_0 [0.1 nm]         |    0.495026  |
# | w_R [cm^-1]          |  145.272     |
# | th_R [rad]           |    0.0811243 |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3472.91     |
# | w2 [cm^-1]           | 1911.37     |
# | l [kcal/mol]         |    6.09409  |
# | x_eq [kcal/mol]      |   -4.52116  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.53039  |
# | R_eq [0.1 nm]        |    0.672928 |
# | R_0 [0.1 nm]         |    0.102773 |
# | w_R [cm^-1]          |  188.164    |
# | th_R [rad]           |    2.71324  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1956.61     |
# | w2 [cm^-1]           | 1696.44     |
# | l [kcal/mol]         |    4.66236  |
# | x_eq [kcal/mol]      |   -3.74099  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.943045 |
# | R_eq [0.1 nm]        |    0.732724 |
# | R_0 [0.1 nm]         |    0.115974 |
# | w_R [cm^-1]          |  259.869    |
# | th_R [rad]           |    1.70025  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 1564.15      |
# | w2 [cm^-1]           | 2073.98      |
# | l [kcal/mol]         |    4.3075    |
# | x_eq [kcal/mol]      |    5.84917   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    0.819314  |
# | R_eq [0.1 nm]        |    0.997742  |
# | R_0 [0.1 nm]         |    0.0530064 |
# | w_R [cm^-1]          |  217.069     |
# | th_R [rad]           |    1.18517   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1763.98     |
# | w2 [cm^-1]           | 3934.28     |
# | l [kcal/mol]         |    4.96576  |
# | x_eq [kcal/mol]      |    1.53409  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.0486   |
# | R_eq [0.1 nm]        |    0.436627 |
# | R_0 [0.1 nm]         |    0.377225 |
# | w_R [cm^-1]          |  159.421    |
# | th_R [rad]           |    2.54196  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3668.97     |
# | w2 [cm^-1]           | 2833.53     |
# | l [kcal/mol]         |    6.05386  |
# | x_eq [kcal/mol]      |    3.12913  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.137    |
# | R_eq [0.1 nm]        |    0.93493  |
# | R_0 [0.1 nm]         |    0.605944 |
# | w_R [cm^-1]          |  291.488    |
# | th_R [rad]           |    0.680563 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2399.42     |
# | w2 [cm^-1]           | 3187.17     |
# | l [kcal/mol]         |    3.0961   |
# | x_eq [kcal/mol]      |    0.971571 |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.39793  |
# | R_eq [0.1 nm]        |    0.328371 |
# | R_0 [0.1 nm]         |    0.175724 |
# | w_R [cm^-1]          |  218.542    |
# | th_R [rad]           |    4.55503  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 1535.81      |
# | w2 [cm^-1]           | 2167.92      |
# | l [kcal/mol]         |    5.54673   |
# | x_eq [kcal/mol]      |    2.92772   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    4.59446   |
# | R_eq [0.1 nm]        |    0.285379  |
# | R_0 [0.1 nm]         |    0.0179408 |
# | w_R [cm^-1]          |  172.578     |
# | th_R [rad]           |    6.02765   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3730.08     |
# | w2 [cm^-1]           | 2035.29     |
# | l [kcal/mol]         |    7.48831  |
# | x_eq [kcal/mol]      |   -7.54124  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.13593  |
# | R_eq [0.1 nm]        |    0.940152 |
# | R_0 [0.1 nm]         |    0.303362 |
# | w_R [cm^-1]          |  248.444    |
# | th_R [rad]           |    5.27561  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2757.27     |
# | w2 [cm^-1]           | 2286.72     |
# | l [kcal/mol]         |    9.98636  |
# | x_eq [kcal/mol]      |   -9.69563  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.23855  |
# | R_eq [0.1 nm]        |    0.684359 |
# | R_0 [0.1 nm]         |    0.148316 |
# | w_R [cm^-1]          |  171.215    |
# | th_R [rad]           |    5.79447  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3923.52     |
# | w2 [cm^-1]           | 2738.59     |
# | l [kcal/mol]         |    4.17501  |
# | x_eq [kcal/mol]      |    3.01763  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    6.01036  |
# | R_eq [0.1 nm]        |    0.271749 |
# | R_0 [0.1 nm]         |    0.262024 |
# | w_R [cm^-1]          |  154.201    |
# | th_R [rad]           |    4.66579  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3536.36     |
# | w2 [cm^-1]           | 2615.1      |
# | l [kcal/mol]         |    1.72077  |
# | x_eq [kcal/mol]      |    2.68917  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.83862  |
# | R_eq [0.1 nm]        |    0.821258 |
# | R_0 [0.1 nm]         |    0.199619 |
# | w_R [cm^-1]          |  274.921    |
# | th_R [rad]           |    4.65285  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1885.95     |
# | w2 [cm^-1]           | 3703.24     |
# | l [kcal/mol]         |    9.30497  |
# | x_eq [kcal/mol]      |   -7.52959  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.04823  |
# | R_eq [0.1 nm]        |    0.930899 |
# | R_0 [0.1 nm]         |    0.171808 |
# | w_R [cm^-1]          |  266.837    |
# | th_R [rad]           |    5.613    |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3753.21     |
# | w2 [cm^-1]           | 2931.91     |
# | l [kcal/mol]         |    8.2627   |
# | x_eq [kcal/mol]      |    9.68382  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.48503  |
# | R_eq [0.1 nm]        |    0.572361 |
# | R_0 [0.1 nm]         |    0.412533 |
# | w_R [cm^-1]          |  169.832    |
# | th_R [rad]           |    3.58915  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1707.4      |
# | w2 [cm^-1]           | 1904.81     |
# | l [kcal/mol]         |    5.50732  |
# | x_eq [kcal/mol]      |    2.64367  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.1622   |
# | R_eq [0.1 nm]        |    0.573446 |
# | R_0 [0.1 nm]         |    0.507967 |
# | w_R [cm^-1]          |  237.699    |
# | th_R [rad]           |    2.27975  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |         Value |
# |----------------------+---------------|
# | V [kcal/mol]         |   10          |
# | w1 [cm^-1]           | 3842.85       |
# | w2 [cm^-1]           | 3031.95       |
# | l [kcal/mol]         |    0.00505848 |
# | x_eq [kcal/mol]      |    4.60335    |
# | w_x [fs^-1]          |    0.0148     |
# | th_x [rad]           |    5.2118     |
# | R_eq [0.1 nm]        |    0.371239   |
# | R_0 [0.1 nm]         |    0.159229   |
# | w_R [cm^-1]          |  126.256      |
# | th_R [rad]           |    4.1262     |
# | m (Proton mass [au]) | 1836          |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2443.11     |
# | w2 [cm^-1]           | 3973.76     |
# | l [kcal/mol]         |    8.31951  |
# | x_eq [kcal/mol]      |   -1.97361  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.06947  |
# | R_eq [0.1 nm]        |    0.653596 |
# | R_0 [0.1 nm]         |    0.651311 |
# | w_R [cm^-1]          |  264.828    |
# | th_R [rad]           |    2.13728  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3888.09     |
# | w2 [cm^-1]           | 2183.94     |
# | l [kcal/mol]         |    0.19937  |
# | x_eq [kcal/mol]      |   -0.811992 |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.8599   |
# | R_eq [0.1 nm]        |    0.809088 |
# | R_0 [0.1 nm]         |    0.781607 |
# | w_R [cm^-1]          |  145.957    |
# | th_R [rad]           |    0.17077  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2330.58     |
# | w2 [cm^-1]           | 2802.31     |
# | l [kcal/mol]         |    4.63643  |
# | x_eq [kcal/mol]      |   -8.93815  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.32886  |
# | R_eq [0.1 nm]        |    0.551302 |
# | R_0 [0.1 nm]         |    0.177573 |
# | w_R [cm^-1]          |  139.63     |
# | th_R [rad]           |    6.00501  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1641.34     |
# | w2 [cm^-1]           | 3654.1      |
# | l [kcal/mol]         |    4.31232  |
# | x_eq [kcal/mol]      |    3.94527  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.346269 |
# | R_eq [0.1 nm]        |    0.824744 |
# | R_0 [0.1 nm]         |    0.575187 |
# | w_R [cm^-1]          |  234.145    |
# | th_R [rad]           |    3.45692  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3046.52     |
# | w2 [cm^-1]           | 3080.08     |
# | l [kcal/mol]         |    4.86017  |
# | x_eq [kcal/mol]      |   -0.42087  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.66804  |
# | R_eq [0.1 nm]        |    0.359865 |
# | R_0 [0.1 nm]         |    0.331478 |
# | w_R [cm^-1]          |  131.563    |
# | th_R [rad]           |    1.09834  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1823.94     |
# | w2 [cm^-1]           | 1683.7      |
# | l [kcal/mol]         |    4.11422  |
# | x_eq [kcal/mol]      |   -5.33608  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.46611  |
# | R_eq [0.1 nm]        |    0.274999 |
# | R_0 [0.1 nm]         |    0.16438  |
# | w_R [cm^-1]          |  200.694    |
# | th_R [rad]           |    2.55695  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2834.45     |
# | w2 [cm^-1]           | 3392.05     |
# | l [kcal/mol]         |    2.89357  |
# | x_eq [kcal/mol]      |    4.48036  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.746407 |
# | R_eq [0.1 nm]        |    0.925479 |
# | R_0 [0.1 nm]         |    0.684848 |
# | w_R [cm^-1]          |  179.967    |
# | th_R [rad]           |    1.55048  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2523.3      |
# | w2 [cm^-1]           | 2320.72     |
# | l [kcal/mol]         |    0.581321 |
# | x_eq [kcal/mol]      |    7.65248  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.53958  |
# | R_eq [0.1 nm]        |    0.574918 |
# | R_0 [0.1 nm]         |    0.437532 |
# | w_R [cm^-1]          |  225.478    |
# | th_R [rad]           |    1.03657  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1920.66     |
# | w2 [cm^-1]           | 1684.95     |
# | l [kcal/mol]         |    7.14942  |
# | x_eq [kcal/mol]      |    3.78951  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.14432  |
# | R_eq [0.1 nm]        |    0.550939 |
# | R_0 [0.1 nm]         |    0.28903  |
# | w_R [cm^-1]          |  299.618    |
# | th_R [rad]           |    2.46345  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3193.7      |
# | w2 [cm^-1]           | 3849.43     |
# | l [kcal/mol]         |    0.59026  |
# | x_eq [kcal/mol]      |    5.79399  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.30019  |
# | R_eq [0.1 nm]        |    0.61974  |
# | R_0 [0.1 nm]         |    0.241022 |
# | w_R [cm^-1]          |  209.42     |
# | th_R [rad]           |    4.61426  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1750.35     |
# | w2 [cm^-1]           | 2020.06     |
# | l [kcal/mol]         |    4.1329   |
# | x_eq [kcal/mol]      |    6.53258  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.90872  |
# | R_eq [0.1 nm]        |    0.341968 |
# | R_0 [0.1 nm]         |    0.299674 |
# | w_R [cm^-1]          |  122.319    |
# | th_R [rad]           |    0.818427 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3106.52     |
# | w2 [cm^-1]           | 3325.55     |
# | l [kcal/mol]         |    3.48197  |
# | x_eq [kcal/mol]      |   -0.524006 |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.725652 |
# | R_eq [0.1 nm]        |    0.535153 |
# | R_0 [0.1 nm]         |    0.32575  |
# | w_R [cm^-1]          |  225.475    |
# | th_R [rad]           |    0.464503 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1598.35     |
# | w2 [cm^-1]           | 2704.02     |
# | l [kcal/mol]         |    9.58575  |
# | x_eq [kcal/mol]      |    5.72888  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.10626  |
# | R_eq [0.1 nm]        |    0.879856 |
# | R_0 [0.1 nm]         |    0.390481 |
# | w_R [cm^-1]          |  222.993    |
# | th_R [rad]           |    5.70397  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3451.03     |
# | w2 [cm^-1]           | 2182.89     |
# | l [kcal/mol]         |    9.40829  |
# | x_eq [kcal/mol]      |    1.40174  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.32108  |
# | R_eq [0.1 nm]        |    0.55183  |
# | R_0 [0.1 nm]         |    0.412196 |
# | w_R [cm^-1]          |  236.426    |
# | th_R [rad]           |    5.68588  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2704.08      |
# | w2 [cm^-1]           | 3889.04      |
# | l [kcal/mol]         |    5.1447    |
# | x_eq [kcal/mol]      |   -1.39196   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    4.03296   |
# | R_eq [0.1 nm]        |    0.38961   |
# | R_0 [0.1 nm]         |    0.0626957 |
# | w_R [cm^-1]          |  251.662     |
# | th_R [rad]           |    1.39625   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2293.57     |
# | w2 [cm^-1]           | 2900.85     |
# | l [kcal/mol]         |    2.79971  |
# | x_eq [kcal/mol]      |    8.92729  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.02632  |
# | R_eq [0.1 nm]        |    0.453761 |
# | R_0 [0.1 nm]         |    0.355763 |
# | w_R [cm^-1]          |  136.111    |
# | th_R [rad]           |    2.671    |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2978.32      |
# | w2 [cm^-1]           | 1742.42      |
# | l [kcal/mol]         |    0.48807   |
# | x_eq [kcal/mol]      |   -2.63138   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    5.96161   |
# | R_eq [0.1 nm]        |    0.807323  |
# | R_0 [0.1 nm]         |    0.0984902 |
# | w_R [cm^-1]          |  299.005     |
# | th_R [rad]           |    2.55173   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3953.34     |
# | w2 [cm^-1]           | 2911.38     |
# | l [kcal/mol]         |    4.17733  |
# | x_eq [kcal/mol]      |   -7.31789  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.24713  |
# | R_eq [0.1 nm]        |    0.328491 |
# | R_0 [0.1 nm]         |    0.319132 |
# | w_R [cm^-1]          |  123.475    |
# | th_R [rad]           |    2.43072  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# ...
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |         Value |
# |----------------------+---------------|
# | V [kcal/mol]         |   10          |
# | w1 [cm^-1]           | 1954.55       |
# | w2 [cm^-1]           | 2339.37       |
# | l [kcal/mol]         |    0.00415371 |
# | x_eq [kcal/mol]      |    1.72417    |
# | w_x [fs^-1]          |    0.0148     |
# | th_x [rad]           |    3.3134     |
# | R_eq [0.1 nm]        |    0.309184   |
# | R_0 [0.1 nm]         |    0.182582   |
# | w_R [cm^-1]          |  281.533      |
# | th_R [rad]           |    5.14373    |
# | m (Proton mass [au]) | 1836          |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1656.55     |
# | w2 [cm^-1]           | 2464.3      |
# | l [kcal/mol]         |    2.3791   |
# | x_eq [kcal/mol]      |   -5.26351  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.29355  |
# | R_eq [0.1 nm]        |    0.562703 |
# | R_0 [0.1 nm]         |    0.224153 |
# | w_R [cm^-1]          |  223.172    |
# | th_R [rad]           |    0.688618 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2058.12     |
# | w2 [cm^-1]           | 1654.96     |
# | l [kcal/mol]         |    9.60835  |
# | x_eq [kcal/mol]      |   -1.22683  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.24134  |
# | R_eq [0.1 nm]        |    0.459026 |
# | R_0 [0.1 nm]         |    0.28134  |
# | w_R [cm^-1]          |  202.254    |
# | th_R [rad]           |    2.54985  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3012.28      |
# | w2 [cm^-1]           | 3938.54      |
# | l [kcal/mol]         |    4.53955   |
# | x_eq [kcal/mol]      |   -3.26772   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    5.35605   |
# | R_eq [0.1 nm]        |    0.961997  |
# | R_0 [0.1 nm]         |    0.0754007 |
# | w_R [cm^-1]          |  276.113     |
# | th_R [rad]           |    1.63735   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3104.55      |
# | w2 [cm^-1]           | 3933.14      |
# | l [kcal/mol]         |    6.79258   |
# | x_eq [kcal/mol]      |    8.64286   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    6.01563   |
# | R_eq [0.1 nm]        |    0.360504  |
# | R_0 [0.1 nm]         |    0.0671691 |
# | w_R [cm^-1]          |  279.889     |
# | th_R [rad]           |    4.988     |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3161.46     |
# | w2 [cm^-1]           | 2193.56     |
# | l [kcal/mol]         |    5.88772  |
# | x_eq [kcal/mol]      |    2.88991  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.31461  |
# | R_eq [0.1 nm]        |    0.29573  |
# | R_0 [0.1 nm]         |    0.151757 |
# | w_R [cm^-1]          |  288.424    |
# | th_R [rad]           |    5.73562  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2798.99     |
# | w2 [cm^-1]           | 2842.97     |
# | l [kcal/mol]         |    5.43131  |
# | x_eq [kcal/mol]      |    3.75666  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.43234  |
# | R_eq [0.1 nm]        |    0.337188 |
# | R_0 [0.1 nm]         |    0.116868 |
# | w_R [cm^-1]          |  242.649    |
# | th_R [rad]           |    2.45929  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2649.13      |
# | w2 [cm^-1]           | 2988.03      |
# | l [kcal/mol]         |    0.352202  |
# | x_eq [kcal/mol]      |    1.03801   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    5.87413   |
# | R_eq [0.1 nm]        |    0.577225  |
# | R_0 [0.1 nm]         |    0.0138036 |
# | w_R [cm^-1]          |  171.447     |
# | th_R [rad]           |    4.26553   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3732.68     |
# | w2 [cm^-1]           | 3538.69     |
# | l [kcal/mol]         |    6.11558  |
# | x_eq [kcal/mol]      |   -3.50197  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.09027  |
# | R_eq [0.1 nm]        |    0.318367 |
# | R_0 [0.1 nm]         |    0.166453 |
# | w_R [cm^-1]          |  164.634    |
# | th_R [rad]           |    5.69402  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3633.15     |
# | w2 [cm^-1]           | 2446.45     |
# | l [kcal/mol]         |    6.13386  |
# | x_eq [kcal/mol]      |    9.66825  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.216333 |
# | R_eq [0.1 nm]        |    0.947246 |
# | R_0 [0.1 nm]         |    0.3024   |
# | w_R [cm^-1]          |  143.437    |
# | th_R [rad]           |    2.22229  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2949.98      |
# | w2 [cm^-1]           | 1813.37      |
# | l [kcal/mol]         |    7.29612   |
# | x_eq [kcal/mol]      |    5.81665   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    5.88818   |
# | R_eq [0.1 nm]        |    0.222408  |
# | R_0 [0.1 nm]         |    0.115853  |
# | w_R [cm^-1]          |  118.002     |
# | th_R [rad]           |    0.0179257 |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3542.1      |
# | w2 [cm^-1]           | 1509.98     |
# | l [kcal/mol]         |    4.61115  |
# | x_eq [kcal/mol]      |    0.193243 |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    5.96565  |
# | R_eq [0.1 nm]        |    0.218415 |
# | R_0 [0.1 nm]         |    0.138233 |
# | w_R [cm^-1]          |  174.632    |
# | th_R [rad]           |    5.31781  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2236.06     |
# | w2 [cm^-1]           | 3685.82     |
# | l [kcal/mol]         |    9.11654  |
# | x_eq [kcal/mol]      |   -4.48103  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    4.66443  |
# | R_eq [0.1 nm]        |    0.314782 |
# | R_0 [0.1 nm]         |    0.277479 |
# | w_R [cm^-1]          |  259.402    |
# | th_R [rad]           |    5.17418  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3775.11     |
# | w2 [cm^-1]           | 3282.31     |
# | l [kcal/mol]         |    6.00938  |
# | x_eq [kcal/mol]      |    5.2181   |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    2.67126  |
# | R_eq [0.1 nm]        |    0.34173  |
# | R_0 [0.1 nm]         |    0.146435 |
# | w_R [cm^-1]          |  190.958    |
# | th_R [rad]           |    0.183004 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3160.43     |
# | w2 [cm^-1]           | 3504.86     |
# | l [kcal/mol]         |    8.52818  |
# | x_eq [kcal/mol]      |    7.94365  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.6803   |
# | R_eq [0.1 nm]        |    0.791885 |
# | R_0 [0.1 nm]         |    0.526213 |
# | w_R [cm^-1]          |  195.781    |
# | th_R [rad]           |    2.53106  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 2369.49      |
# | w2 [cm^-1]           | 3913.62      |
# | l [kcal/mol]         |    0.0467446 |
# | x_eq [kcal/mol]      |   -9.40144   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    3.25475   |
# | R_eq [0.1 nm]        |    0.339991  |
# | R_0 [0.1 nm]         |    0.292897  |
# | w_R [cm^-1]          |  231.149     |
# | th_R [rad]           |    3.35115   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2498.99     |
# | w2 [cm^-1]           | 2224.23     |
# | l [kcal/mol]         |    3.53109  |
# | x_eq [kcal/mol]      |   -4.65885  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.252871 |
# | R_eq [0.1 nm]        |    0.447942 |
# | R_0 [0.1 nm]         |    0.414472 |
# | w_R [cm^-1]          |  268.513    |
# | th_R [rad]           |    0.858628 |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3337.85     |
# | w2 [cm^-1]           | 3882.42     |
# | l [kcal/mol]         |    7.38311  |
# | x_eq [kcal/mol]      |    3.11003  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    6.22927  |
# | R_eq [0.1 nm]        |    0.465864 |
# | R_0 [0.1 nm]         |    0.268913 |
# | w_R [cm^-1]          |  192.153    |
# | th_R [rad]           |    5.13233  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2218.94     |
# | w2 [cm^-1]           | 3012.51     |
# | l [kcal/mol]         |    2.07053  |
# | x_eq [kcal/mol]      |   -3.20301  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.08424  |
# | R_eq [0.1 nm]        |    0.504757 |
# | R_0 [0.1 nm]         |    0.229566 |
# | w_R [cm^-1]          |  149.025    |
# | th_R [rad]           |    3.99397  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 3522.12      |
# | w2 [cm^-1]           | 2731.43      |
# | l [kcal/mol]         |    0.19884   |
# | x_eq [kcal/mol]      |   -1.89394   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    2.38383   |
# | R_eq [0.1 nm]        |    0.420491  |
# | R_0 [0.1 nm]         |    0.0646212 |
# | w_R [cm^-1]          |  278.868     |
# | th_R [rad]           |    1.2556    |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1982.64     |
# | w2 [cm^-1]           | 3666.14     |
# | l [kcal/mol]         |    7.98563  |
# | x_eq [kcal/mol]      |   -1.75425  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.50795  |
# | R_eq [0.1 nm]        |    0.426201 |
# | R_0 [0.1 nm]         |    0.208509 |
# | w_R [cm^-1]          |  135.611    |
# | th_R [rad]           |    2.04264  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |        Value |
# |----------------------+--------------|
# | V [kcal/mol]         |   10         |
# | w1 [cm^-1]           | 1943.73      |
# | w2 [cm^-1]           | 2793.99      |
# | l [kcal/mol]         |    9.86396   |
# | x_eq [kcal/mol]      |   -1.30055   |
# | w_x [fs^-1]          |    0.0148    |
# | th_x [rad]           |    5.43728   |
# | R_eq [0.1 nm]        |    0.460406  |
# | R_0 [0.1 nm]         |    0.0349242 |
# | w_R [cm^-1]          |  261.106     |
# | th_R [rad]           |    5.08429   |
# | m (Proton mass [au]) | 1836         |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2849.26     |
# | w2 [cm^-1]           | 3693.16     |
# | l [kcal/mol]         |    6.12637  |
# | x_eq [kcal/mol]      |    3.45345  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.97917  |
# | R_eq [0.1 nm]        |    0.576247 |
# | R_0 [0.1 nm]         |    0.112591 |
# | w_R [cm^-1]          |  107.242    |
# | th_R [rad]           |    2.21815  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 1817.99     |
# | w2 [cm^-1]           | 2424.01     |
# | l [kcal/mol]         |    3.9077   |
# | x_eq [kcal/mol]      |   -4.75782  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.03208  |
# | R_eq [0.1 nm]        |    0.725935 |
# | R_0 [0.1 nm]         |    0.387407 |
# | w_R [cm^-1]          |  115.778    |
# | th_R [rad]           |    3.49387  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3821.48     |
# | w2 [cm^-1]           | 3599.31     |
# | l [kcal/mol]         |    9.95389  |
# | x_eq [kcal/mol]      |    9.16803  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    0.694283 |
# | R_eq [0.1 nm]        |    0.726298 |
# | R_0 [0.1 nm]         |    0.411987 |
# | w_R [cm^-1]          |  243.768    |
# | th_R [rad]           |    3.82476  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 2649.32     |
# | w2 [cm^-1]           | 3985.98     |
# | l [kcal/mol]         |    5.45478  |
# | x_eq [kcal/mol]      |   -7.55671  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    1.14783  |
# | R_eq [0.1 nm]        |    0.282492 |
# | R_0 [0.1 nm]         |    0.107736 |
# | w_R [cm^-1]          |  150.693    |
# | th_R [rad]           |    5.15454  |
# | m (Proton mass [au]) | 1836        |
# ====== Time Dependent Potential ======
#
# | Variable             |       Value |
# |----------------------+-------------|
# | V [kcal/mol]         |   10        |
# | w1 [cm^-1]           | 3128.73     |
# | w2 [cm^-1]           | 2137.39     |
# | l [kcal/mol]         |    6.22781  |
# | x_eq [kcal/mol]      |    7.41486  |
# | w_x [fs^-1]          |    0.0148   |
# | th_x [rad]           |    3.05874  |
# | R_eq [0.1 nm]        |    0.401044 |
# | R_0 [0.1 nm]         |    0.178165 |
# | w_R [cm^-1]          |  258.548    |
# | th_R [rad]           |    1.20705  |
# | m (Proton mass [au]) | 1836        |
